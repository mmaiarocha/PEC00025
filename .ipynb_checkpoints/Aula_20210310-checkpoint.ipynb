# %% [markdown]
# Vou fazer um cálculo envolvendo as variáveis $a$, $b$ e $c$...

# %%
a = 1
b = 2
c = a + b

print(c)
# Out:
# 3

# %% [markdown]
# O cálculo acima corresponde à formula:
#
# $$ c = a + b $$
#
# Gostou?

# %% [markdown]
# <img src="resources/tests/P1_2019_fig1.png" alt="Prova P1" width="600px"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 200)
y = np.sin(2*x)

plt.figure(1)
plt.plot(x,y)

# %% [markdown]
# Essa é uma célula Markdown. Essa célula aceita $\LaTeX$, html e markdown.
#
# Markdown é um html simplificado!!!
#
# # 1. Título
#
# ## 1.1. Subtítulo
#
# ### 1.1.1. Subsubtítulo ...
#
#
# Isso é texto normal, _isso é texto itálico_, **isso é texto bold**.
#
# Para numerar itens:
#
# 1. Item 1
# 2. Item 2
#
# Para lista não numerada:
#
# * Item 1
# * Item 2
