# %% [markdown]
# # Título
# ## Subtítulo
#
# * Item 1
# * Item 2
#
# 1. Item 1
# 2. Item 2
#
# Vamos definir $a = 1$ e $b = 2$. Conclui-se que:
#
# $$ c = a + b = 3 $$

# %%
a = 1
b = 2
c = a + b

print(f'The sum of {a:3.1f} and {b:3.1f} is {c:3.1f}')

# %% [markdown]
# $$ I = \int_{0}^{\infty} {\frac{x^2}{2} \, dx}
